# %%
pip install geopandas

# %%
import geopandas
import fiona
import matplotlib.pyplot as plt

# %%
microreg = geopandas.read_file("microreg.gpkg")
microreg
# Out:
#                            NM_MICRO CD_GEOCMI    micro     ano         total  \
# 0                        ADAMANTINA     35035  35035.0  2020.0  1.594145e+05
# 1                    AFONSO CLÁUDIO     32007  32007.0  2020.0  1.329172e+05
# 2    AGLOMERAÇÃO URBANA DE SÃO LUÍS     21002  21002.0  2020.0  1.338933e+06
# 3              AGRESTE DE ITABAIANA     28004  28004.0  2020.0  1.621635e+05
# 4                AGRESTE DE LAGARTO     28006  28006.0  2020.0  1.156281e+05
# ..                              ...       ...      ...     ...           ...
# 553            VITÓRIA DA CONQUISTA     29028  29028.0  2020.0  6.289954e+05
# 554          VITÓRIA DE SANTO ANTÃO     26014  26014.0  2020.0  2.175390e+05
# 555                     VOTUPORANGA     35003  35003.0  2020.0  1.410361e+05
# 556                  WENCESLAU BRAZ     41018  41018.0  2020.0  9.901895e+04
# 557                         XANXERÊ     42003  42003.0  2020.0  1.536435e+05
#
# ...

# %%
microreg.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NM_MICRO   558 non-null    object
#  1   CD_GEOCMI  558 non-null    object
#  2   micro      558 non-null    float64
#  3   ano        558 non-null    float64
#  4   total      558 non-null    float64
#  5   Fx18       558 non-null    float64
#  6   Fx60       558 non-null    float64
#  7   Fx70       558 non-null    float64
#  8   Fx80       557 non-null    float64
#  9   pp_fx18    558 non-null    float64
#  10  pp_60      558 non-null    float64
#  11  pp_70      558 non-null    float64
#  12  pp_80      557 non-null    float64
#  13  geometry   558 non-null    geometry
# dtypes: float64(11), geometry(1), object(2)
# memory usage: 61.2+ KB

# %%
microreg.plot(column = 'micro')

# %%
microreg.plot(column = 'total')

# %%
microreg.plot(column = 'Fx60')

# %%
fig, ax = plt.subplots(1, 1)
microreg.plot(column = 'pp_60', 
              ax=ax, 
              legend=True)

# %%
fig, ax = plt.subplots(1, 1)
microreg.plot(column = 'pp_80', 
              ax=ax, 
              legend=True,
              missing_kwds={"color": "lightgrey",
                            "edgecolor": "red",
                            "hatch": "///",
                            "label": "Missing values"},)
